# %% [markdown]
# <a href="https://colab.research.google.com/github/BhaveshWadibhasme/Generative-AI/blob/main/Create_vector_database.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain
# !pip install playwright
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.1/803.1 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 21.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.7/205.7 kB 18.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.2/37.2 MB 13.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.2/613.2 kB 56.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: greenlet
#     Found existing installation: greenlet 3.0.2
#     Uninstalling greenlet-3.0.2:
#       Successfully uninstalled greenlet-3.0.2
# ...

# %%
# !playwright install
# Out:
# ...
# 153.1 Mb [] 0% 10.2s153.1 Mb [] 0% 41.5s153.1 Mb [] 0% 30.9s153.1 Mb [] 0% 16.8s153.1 Mb [] 0% 14.5s153.1 Mb [] 1% 9.4s153.1 Mb [] 1% 7.7s153.1 Mb [] 1% 6.7s153.1 Mb [] 2% 5.9s153.1 Mb [] 2% 5.7s153.1 Mb [] 3% 5.5s153.1 Mb [] 3% 5.1s153.1 Mb [] 4% 5.5s153.1 Mb [] 4% 5.2s153.1 Mb [] 4% 5.1s153.1 Mb [] 5% 5.0s153.1 Mb [] 5% 4.9s153.1 Mb [] 6% 4.9s153.1 Mb [] 7% 4.7s153.1 Mb [] 7% 4.6s153.1 Mb [] 7% 4.5s153.1 Mb [] 8% 4.5s153.1 Mb [] 8% 4.4s153.1 Mb [] 9% 4.1s153.1 Mb [] 10% 3.9s153.1 Mb [] 11% 3.7s153.1 Mb [] 12% 3.5s153.1 Mb [] 13% 3.4s153.1 Mb [] 13% 3.3s153.1 Mb [] 14% 3.3s153.1 Mb [] 15% 3.2s153.1 Mb [] 16% 3.1s153.1 Mb [] 17% 3.0s153.1 Mb [] 19% 2.8s153.1 Mb [] 20% 2.7s153.1 Mb [] 20% 2.6s153.1 Mb [] 21% 2.6s153.1 Mb [] 22% 2.5s153.1 Mb [] 23% 2.4s153.1 Mb [] 24% 2.3s153.1 Mb [] 25% 2.2s153.1 Mb [] 27% 2.2s153.1 Mb [] 28% 2.1s153.1 Mb [] 29% 2.0s153.1 Mb [] 30% 1.9s153.1 Mb [] 31% 1.8s153.1 Mb [] 32% 1.8s153.1 Mb [] 34% 1.7s153.1 Mb [] 35% 1.7s153.1 Mb [] 36% 1.6s153.1 Mb [] 37% 1
# ...

# %%
# !pip install html2text

# %%
# !pip install sentence-transformers
# !pip install faiss-gpu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 11.3 MB/s eta 0:00:00
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=1c0143b488ed61cb7c7825bd1450f2ed81575d32a46e942eb6a6a645af124577
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 6.8 MB/s eta 0:00:00
# ...

# %%
from langchain.text_splitter import CharacterTextSplitter
from langchain.document_loaders import AsyncChromiumLoader
from langchain.document_transformers import Html2TextTransformer
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
import nest_asyncio

nest_asyncio.apply()

articles = ["https://www.fantasypros.com/2023/11/rival-fantasy-nfl-week-10/",
            "https://www.fantasypros.com/2023/11/5-stats-to-know-before-setting-your-fantasy-lineup-week-10/",
            "https://www.fantasypros.com/2023/11/nfl-week-10-sleeper-picks-player-predictions-2023/",
            "https://www.fantasypros.com/2023/11/nfl-dfs-week-10-stacking-advice-picks-2023-fantasy-football/",
            "https://www.fantasypros.com/2023/11/players-to-buy-low-sell-high-trade-advice-2023-fantasy-football/"]

# Scrapes the blogs above
loader = AsyncChromiumLoader(articles)
docs = loader.load()

# Converts HTML to plain text
html2text = Html2TextTransformer()
docs_transformed = html2text.transform_documents(docs)

# Chunk text
text_splitter = CharacterTextSplitter(chunk_size=100,
                                      chunk_overlap=0)
chunked_documents = text_splitter.split_documents(docs_transformed)

# Load chunked documents into the FAISS index
db = FAISS.from_documents(chunked_documents,
                          HuggingFaceEmbeddings(model_name='sentence-transformers/all-mpnet-base-v2'))


# Connect query to FAISS index using a retriever
retriever = db.as_retriever(
    search_type="similarity",
    search_kwargs={'k': 4}
)
# Out:
# WARNING:langchain.text_splitter:Created a chunk of size 146, which is longer than the specified 100
# WARNING:langchain.text_splitter:Created a chunk of size 4148, which is longer than the specified 100
# WARNING:langchain.text_splitter:Created a chunk of size 131, which is longer than the specified 100
# WARNING:langchain.text_splitter:Created a chunk of size 230, which is longer than the specified 100
# WARNING:langchain.text_splitter:Created a chunk of size 500, which is longer than the specified 100
# WARNING:langchain.text_splitter:Created a chunk of size 207, which is longer than the specified 100
# WARNING:langchain.text_splitter:Created a chunk of size 365, which is longer than the specified 100
# WARNING:langchain.text_splitter:Created a chunk of size 312, which is longer than the specified 100
# WARNING:langchain.text_splitter:Created a chunk of size 515, which is longer than the specified 100
# ...

# %%
query = "What did Laporta say?"
docs = db.similarity_search(query)
print(docs[0].page_content)
# Out:
# . I tapped LaPorta due to a more favorable matchup.

# %%
docs
# Out:
# [Document(page_content='. I tapped LaPorta due to a more favorable matchup.', metadata={'source': 'https://www.fantasypros.com/2023/11/rival-fantasy-nfl-week-10/'}),
#  Document(page_content='“There seemed to be a healthy skepticism when Will Levis', metadata={'source': 'https://www.fantasypros.com/2023/11/players-to-buy-low-sell-high-trade-advice-2023-fantasy-football/'}),
#  Document(page_content=', Puka Nacua\n\nand Davante Adams\n\n.”  \n– Smitty (TheFantasyFootballShow)', metadata={'source': 'https://www.fantasypros.com/2023/11/players-to-buy-low-sell-high-trade-advice-2023-fantasy-football/'}),
#  Document(page_content='(ankle) doing what he can to play in finale\n\nTua Tagovailoa\n\nSuffers shoulder injury Sunday', metadata={'source': 'https://www.fantasypros.com/2023/11/5-stats-to-know-before-setting-your-fantasy-lineup-week-10/'})]
